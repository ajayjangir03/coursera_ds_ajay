# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# #  Data Science Tools and Ecosystem

# %% [markdown]
# #### In this notebook, I would like to summerize about Data Science ecosystem such as libraries , langauges and hands on experience with basic python code

# %% [markdown]
# ##### Some of the popular that data scientists use are :
# 1. Pyhton
# 2. R
# 3. SQL
# 4. Juila
# 5. Scala

# %% [markdown]
# ##### Some of the commonly used libraries used by Data Scientists include:
# 1. NumPy
# 2. Pandas
# 3. Matplotlib
# 4. Scikit-learn
# 5. TensorFlow

# %% [markdown]
# ##### Data Science Tools are :
# 1. Jupyter Notebook
# 2. RStudio
# 3. VS Code

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# Create a code cell to multiply and add numbers
a = 3
b = 4
c = 5
#arithmetic expression to mutiply then add integers
add_mul = (a*b)+c
#printing final output 
print(add_mul)
# Out:
# 17

# %%
#Create a code cell to convert minutes to hours
min = 200
#converting minutes to hours
hrs = min/60
print(hrs)
# Out:
# 3.3333333333333335

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science
# - Identify commonly used Data Science libraries
# - Create tables of Data Science tools
# - Demonstrate arithmetic expression examples in Python
# - Understand basic Python code execution in a Jupyter Notebook

# %% [markdown]
# ## Author
# Ajay
